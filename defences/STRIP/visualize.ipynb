# %%
import numpy as np
import matplotlib.pyplot as plt


def draw(f1,f2,out):
    with open(f1, 'r') as file:
        entropy_trojan_trojan = file.read()
    with open(f2, 'r') as file:
        entropy_trojan_clean = file.read()
    entropy_trojan_trojan=[float(i) for i in entropy_trojan_trojan.split(' ')]
    entropy_trojan_clean=[float(i) for i in entropy_trojan_clean.split(' ')]
    print(max(entropy_trojan_clean),min(entropy_trojan_clean))
    print(max(entropy_trojan_trojan),min(entropy_trojan_trojan))
    bins = 20

    # 画直方图
    plt.hist(entropy_trojan_trojan, bins, weights=np.ones(len(entropy_trojan_trojan)) / len(entropy_trojan_trojan), alpha=0.5, label='with trojan')
    plt.hist(entropy_trojan_clean, bins, weights=np.ones(len(entropy_trojan_clean)) / len(entropy_trojan_clean), alpha=0.5, label='without trojan')

    plt.legend(loc='upper right', fontsize = 20)
    plt.ylabel('Probability (%)', fontsize = 20)
    plt.title('normalized entropy', fontsize = 20)
    plt.tick_params(labelsize=20)
    fig1 = plt.gcf()
    plt.savefig(out)
    plt.show()

# draw('results/stl10/attack/stl10-cifar10_attack_output_trojan.txt', 'results/stl10/attack/stl10-cifar10_attack_output_clean.txt','results/stl10/attack/stl10-cifar10.png')
# draw('results/stl10/attack/stl10_svhn_attack_output_trojan.txt', 'results/stl10/attack/stl10_svhn_attack_output_clean.txt','results/stl10/attack/stl10-svhn.png')
# draw('results/stl10/attack/stl10_gtsrb_attack_output_trojan.txt', 'results/stl10/attack/stl10_gtsrb_attack_output_clean.txt','results/stl10/attack/stl10-gtsrb.png')

# draw('results/cifar10/attack/cifar10_stl10_attack_output_trojan.txt', 'results/cifar10/attack/cifar10_stl10_attack_output_clean.txt','results/cifar10/attack/cifar-stl10.png')
# draw('results/cifar10/attack/cifar10_svhn_attack_output_trojan.txt', 'results/cifar10/attack/cifar10_svhn_attack_output_clean.txt','results/cifar10/attack/cifar-svhn.png')
draw('results/cifar10/attack/cifar10_gtsrb_attack_output_trojan.txt', 'results/cifar10/attack/cifar10_gtsrb_attack_output_clean.txt','results/cifar10/attack/cifar-gtsrb.png')
# Out:
# 4.455085047538887e-09 1.052982744424748e-23
# 1.7539247210152097e-09 1.7865180701939982e-23

# %%
import numpy as np
import matplotlib.pyplot as plt


def draw(f1,f2,out):
    with open(f1, 'r') as file:
        entropy_trojan_trojan = file.read()
    with open(f2, 'r') as file:
        entropy_trojan_clean = file.read()
    entropy_trojan_trojan=[float(i) for i in entropy_trojan_trojan.split(' ')]
    entropy_trojan_clean=[float(i) for i in entropy_trojan_clean.split(' ')]
    bins = 50

    # 画直方图
    # plt.hist(entropy_trojan_trojan, bins, weights=np.ones(len(entropy_trojan_trojan)) / len(entropy_trojan_trojan), alpha=0.5, label='with trojan')
    # plt.hist(entropy_trojan_clean, bins, weights=np.ones(len(entropy_trojan_clean)) / len(entropy_trojan_clean), alpha=0.5, label='without trojan')
    plt.hist(entropy_trojan_trojan, bins='auto', alpha=0.5, label='with trojan')
    plt.hist(entropy_trojan_clean, bins='auto', alpha=0.5, label='without trojan')

    plt.legend(loc='upper right', fontsize = 20)
    plt.ylabel('Probability (%)', fontsize = 20)
    plt.title('normalized entropy', fontsize = 20)
    plt.tick_params(labelsize=20)
    fig1 = plt.gcf()
    plt.savefig(out)
    plt.show()

# draw('results/stl10/attack/stl10-cifar10_attack_output_trojan.txt', 'results/stl10/attack/stl10-cifar10_attack_output_clean.txt','results/stl10/attack/stl10-cifar10.png')
# draw('results/stl10/attack/stl10_svhn_attack_output_trojan.txt', 'results/stl10/attack/stl10_svhn_attack_output_clean.txt','results/stl10/attack/stl10-svhn.png')
# draw('results/stl10/attack/stl10_gtsrb_attack_output_trojan.txt', 'results/stl10/attack/stl10_gtsrb_attack_output_clean.txt','results/stl10/attack/stl10-gtsrb.png')

# draw('results/cifar10/attack/cifar10_stl10_attack_output_trojan.txt', 'results/cifar10/attack/cifar10_stl10_attack_output_clean.txt','results/cifar10/attack/cifar-stl10.png')
# draw('results/cifar10/attack/cifar10_svhn_attack_output_trojan.txt', 'results/cifar10/attack/cifar10_svhn_attack_output_clean.txt','results/cifar10/attack/cifar-svhn.png')
draw('results/cifar10/attack/cifar10_gtsrb_attack_output_trojan.txt', 'results/cifar10/attack/cifar10_gtsrb_attack_output_clean.txt','results/cifar10/attack/cifar-gtsrb.png')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
with open('results/cifar10/attack/cifar10_gtsrb_attack_output_clean.txt', 'r') as file:
    entropy_trojan_clean = file.read()
np.ones(len(entropy_trojan_clean)) / len(entropy_trojan_clean)
# Out:
# array([4.47207191e-05, 4.47207191e-05, 4.47207191e-05, ...,
#        4.47207191e-05, 4.47207191e-05, 4.47207191e-05])

# %%
entropy_trojan_clean
# Out:
# '4.027970179620866e-12 8.99538429854907e-14 8.991252749870928e-19 5.973120331681514e-12 1.3904785656215778e-12 5.566326843897684e-12 5.572168160911106e-14 1.1625139739734892e-12 1.719919508463147e-15 7.57371324943551e-15 8.156849327922711e-14 4.876388355612438e-14 1.868163691234534e-15 1.2080843053360879e-14 4.933008754086365e-16 6.422837262043402e-12 6.876412518553015e-17 4.837073797059333e-13 1.2079977643186801e-13 3.549768375836308e-16 8.350783259336581e-13 1.2205515461174987e-14 5.13908089260634e-15 1.12203711599701e-12 2.002795065209062e-14 7.82785569697353e-11 3.620424814977652e-15 4.482177704077245e-15 5.080248374755847e-13 6.277032713053465e-14 1.58066005291304e-20 1.0428671814999291e-14 1.4329785764293033e-18 7.168422668615433e-21 1.6874933423543808e-17 3.658205960377359e-12 9.515819592361026e-20 5.5023264488804084e-17 5.921261241886522e-19 9.00124213446679e-15 1.3864818442990237e-19 4.503778471482746e-18 8.229490212370024e-19 9.15927827857107e-19 1.8968085243898378e-17 1.76
# ...

# %%
with open('results/cifar10/attack/cifar10_svhn_attack_output_clean.txt', 'r') as file:
    entropy_trojan_clean = file.read()
np.ones(len(entropy_trojan_clean)) / len(entropy_trojan_clean)
# Out:
# array([5.28317836e-05, 5.28317836e-05, 5.28317836e-05, ...,
#        5.28317836e-05, 5.28317836e-05, 5.28317836e-05])

# %%
entropy_trojan_clean
# Out:
# '0.6039136505126953 0.43615333557128905 0.5730778884887695 0.6043184280395508 0.5484496307373047 0.5430218505859375 0.515470962524414 0.5984619903564453 0.48988502502441406 0.5352410507202149 0.4340576171875 0.5774088668823242 0.5324024963378906 0.48457237243652346 0.5608890533447266 0.58312744140625 0.5548728561401367 0.4954261779785156 0.4847679901123047 0.5595927429199219 0.6330237579345703 0.596334228515625 0.5115480041503906 0.5155426025390625 0.45380615234375 0.49812652587890627 0.4711056137084961 0.5254466247558593 0.5330229568481445 0.5276822662353515 0.47977508544921876 0.4280112838745117 0.594793930053711 0.642748031616211 0.45181095123291015 0.520204086303711 0.5752848052978515 0.6638727569580078 0.48581489562988284 0.5831922149658203 0.5065637969970703 0.5058036422729493 0.5348158264160157 0.4720948791503906 0.5309717559814453 0.5213848876953125 0.616427993774414 0.47936180114746096 0.5712425231933593 0.6094425201416016 0.6192923355102539 0.5354042816162109 0.557299194335
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# 图片路径
cifar1='results/cifar10/attack/cifar-stl10.png'
cifar2='results/cifar10/attack/cifar-svhn.png'
stl1='results/stl10/attack/stl10-cifar10.png'
stl2='results/stl10/attack/stl10-svhn.png'

# 读取图片
img1 = mpimg.imread(cifar1)
img2 = mpimg.imread(cifar2)
img3 = mpimg.imread(stl1)
img4 = mpimg.imread(stl2)

# 创建一个新的图形
fig, axs = plt.subplots(1, 4, figsize=(23, 5))

# 在子图上显示图片
axs[0].imshow(img1)
axs[0].axis('off')  # 不显示坐标轴
axs[0].set_title('CIFAR10-STL10', fontsize=20)  # 设置标题

axs[1].imshow(img2)
axs[1].axis('off')
axs[1].set_title('CIFAR10-SVHN', fontsize=20)  # 设置标题

axs[2].imshow(img3)
axs[2].axis('off')
axs[2].set_title('STL10-CIFAR10', fontsize=20)  # 设置标题

axs[3].imshow(img4)
axs[3].axis('off')
axs[3].set_title('STL10-SVHN', fontsize=20)  # 设置标题

fig.tight_layout()  # 自动调整子图间距
# 显示图形
# plt.show()
fig.savefig('results/strip.png')
